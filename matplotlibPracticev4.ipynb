# %%
from matplotlib import pyplot as plt

# %%
with plt.xkcd():
    days = [1,2,3,4,5,6,7,8]

    dev1 = [8, 8, 7, 6, 6, 4, 0, 0]
    dev2 = [0, 0, 1, 1, 2, 1, 3, 2]
    dev3 = [0, 0, 0, 1, 0, 3, 5, 6]

    #plt.style.use('fivethirtyeight')

    labels = ['dev1', 'dev2', 'dev3']
    colors = ['#5B2C6F', '#F4D03F', '#2C3E50']

    plt.stackplot(days, dev1, dev2, dev3, colors=colors, labels=labels)

    plt.title('Simple Stack Plot')
    plt.legend(loc='lower left')
    plt.tight_layout()
    plt.grid(False)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']
